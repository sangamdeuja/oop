# %%
#creating class Employee
class Employee:
    #counting the number of employee object by assigning class variable employee_count
    employee_count=0
    def __init__(self,first_name=None,rank=0,last_name=None,pay=1000):
        self.first_name=first_name
        self.rank=rank
        self.last_name=last_name
        self.pay=pay
        emlpoyee_count+=1
        
    #class method to create the email id   
    def email_id(self):
        return f'{self.first_name}.{self.last_name}@email.com'
    
    #using static method to dermine even/odd day
    @staticmethod
    def is_even_day(num):
        if num%2==0:
            return True
        return False
    
    #promote the rank of the employee
    def promote(self):
        self.promote+=1
    
    #raise the salary of the employee by specific amount
    def raise_salary(self,amount):
        self.pay=self.pay+amount
    
    #class method for email notification to all the employee
    @classmethod
    def end_email(cls):
        return "email sent"
    
    #getter and setter method to allow data enacpsulation     
    @property
    def getting_pay(self):
        return self.__pay
    
    @getting_pay.setter
    def getting_pay(self,pay):
        if pay<1000:
            self.__pay=pay
            
    # returns the object type as "Employee object"       
    def __repr__(self):
        return "Employee object"
    
#New class Ballerina inheriting the Employee class with additional dances attribute
class Ballerina(Employee):
    def __init__(self,first_name,rank,last_name,pay,dances):
        Employee.__init__(self,first_name,rank,last_name,pay)
        self.dances=dances
        
#The above inheritence can be done using super() as follows:
class Ballerina(Employee):
    def __init__(self,first_name,rank,last_name,pay,dances):
        super().__init__(self,first_name,rank,last_name,pay)
        self.dances=dances
